# %%
import requests
import getpass

api_key = getpass.getpass("Enter your OpenRouter API key: ")
API_URL = "https://openrouter.ai/api/v1/chat/completions"

# ✅ Switch to a lower-cost model
MODEL_NAME = "mistralai/mistral-small"  # Use Mistral Small for lower token usage

def chat_with_openrouter():
    print("Chatbot: Hello! Type 'exit' to end the conversation.")

    conversation = []

    while True:
        user_input = input("You: ")
        if user_input.lower() == "exit":
            print("Chatbot: Goodbye!")
            break

        # ✅ Keep only the last 5 messages to save tokens
        if len(conversation) > 5:
            conversation = conversation[-5:]

        conversation.append({"role": "user", "content": user_input})

        payload = {
            "model": MODEL_NAME,
            "messages": conversation
        }

        headers = {
            "Authorization": f"Bearer {api_key}",
            "Content-Type": "application/json"
        }

        response = requests.post(API_URL, json=payload, headers=headers)

        try:
            response_json = response.json()

            if response.status_code == 200 and "choices" in response_json:
                reply = response_json["choices"][0]["message"]["content"]
                print(f"Chatbot: {reply}")
                conversation.append({"role": "assistant", "content": reply})
            else:
                print(f"API Error: {response_json}")  # Print error response

        except Exception as e:
            print(f"Unexpected Error: {e}")

# Run the chatbot
chat_with_openrouter()
# Out:
# Enter your OpenRouter API key: ··········
# Chatbot: Hello! Type 'exit' to end the conversation.
# You: Hii
# Chatbot: Hello! How are you doing today?
# You: Yeahh good,Can you give some information about chatbot AI
# Chatbot: Sure! Chatbot AI refers to artificial intelligence technologies used to create chatbots, which are automated computer programs designed to simulate conversation with human users. Here are some key aspects of chatbot AI:
#
# ### Types of Chatbots
#
# 1. **Rule-Based Chatbots**: These are the simplest type of chatbots that respond based on predefined rules and if-else statements. They are easy to create but lack the ability to understand context or learn.
#
# 2. **Retrieval-Based Chatbots**: These use a large database of pre-written responses and retrieve the most suitable one based on user input. They can handle a broader range of queries but still lack context understanding.
#
# 3. **Generative Chatbots**: These use machine learning models, often based on natural language processing (NLP) algorithms, to generate responses dynamically. They can understand context, learn from interactions, and improve over time.
#
# ### Key Components of Chatbot AI
#
# 1. **Natural Language Processing (NLP)**: NLP enables chatbots to understand, interpret, and generate human language. Techniques like tokenization, sentiment analysis, and named entity recognition are crucial for this.
#
# 2. **Machine Learning (ML)**: ML algorithms allow chatbots to learn from data and improve their responses over time. Algorithms can include supervised learning, reinforcement learning, and others.
#
# 3. **Dialog Management**: This component handles the flow of the conversation, managing context and maintaining coherence between user inputs and bot responses.
#
# 4. **Intent Recognition**: The ability to identify the purpose or goal of a user's input is crucial. Intent recognition helps the chatbot respond appropriately and accurately.
#
# 5. **Entity Recognition**: This involves identifying and extracting relevant information (like dates, names, locations) from user inputs to provide more meaningful responses.
#
# ### Applications of Chatbot AI
#
# - **Customer Service**: Chatbots can handle customer inquiries, provide support, and resolve issues 24/7.
# - **E-commerce**: They can assist customers in finding products, making purchases, and tracking orders.
# - **Healthcare**: Chatbots can provide health information, schedule appointments, and even monitor patients.
# - **Education**: Chatbots can assist students with learning and provide quick answers to questions.
# - **Entertainment**: They can engage users in conversations, play games, and provide personalized content.
#
# ### Challenges of Chatbot AI
#
# 1. **Understanding Context**: Chatbots often struggle with understanding the nuances and context of human language.
# 2. **Handling Ambiguity**: Human language is full of ambiguities, and chatbots must be equipped to handle them effectively.
# 3. **Personalization**: Providing personalized responses that feel natural and human-like can be challenging.
# 4. **Scalability**: As chatbots scale to handle more users and queries, maintaining performance and efficiency becomes essential.
#
# ### Future Trends
#
# 1. **Advanced NLP Techniques**: New advancements in NLP, such as transformer models (e.g., BERT), are improving the accuracy and contextual understanding of chatbots.
# 2. **Multimodal Chatbots**: Combining text with other modalities like images, voice, and video for more immersive experiences.
# 3. **Emotion Recognition**: Incorporating emotion recognition to make interactions more empathetic and human-like.
# You: exit
# Chatbot: Goodbye!
